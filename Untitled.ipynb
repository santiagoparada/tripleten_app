# %%
import pandas as pd

df = pd.read_csv('Registro_de_mediciones_de_campos_electromagn_ticos_-_RNI.csv')

print(df.shape)
print(df.columns.tolist())
# Out:
# (24994156, 7)
# ['ubicacion_sonda', 'ciudad', 'fecha_medicion', 'intensidad_campo', 'máximo_permitido', 'porcentaje_intensidad_campo', 'georreferencia']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24994156 entries, 0 to 24994155
# Data columns (total 7 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   ubicacion_sonda              str
#  1   ciudad                       str
#  2   fecha_medicion               str
#  3   intensidad_campo             float64
#  4   máximo_permitido             int64
#  5   porcentaje_intensidad_campo  float64
#  6   georreferencia               str
# dtypes: float64(2), int64(1), str(4)
# memory usage: 3.4 GB

# %%
df.head()
# Out:
#      ubicacion_sonda         ciudad          fecha_medicion  intensidad_campo  \
# 0  Popayan_LA_LADERA  Popayan_CAUCA  2020/05/20 11:36:00 PM              0.09
# 1  Popayan_LA_LADERA  Popayan_CAUCA  2020/05/20 11:42:00 PM              0.12
# 2  Popayan_LA_LADERA  Popayan_CAUCA  2020/05/20 11:48:00 PM              0.12
# 3  Popayan_LA_LADERA  Popayan_CAUCA  2020/05/20 11:54:00 PM              0.09
# 4  Popayan_LA_LADERA  Popayan_CAUCA  2020/05/21 12:00:00 AM              0.09
#
#    máximo_permitido  porcentaje_intensidad_campo           georreferencia
# 0                28                         0.32  POINT (-76.6183 2.4332)
# 1                28                         0.43  POINT (-76.6183 2.4332)
# 2                28                         0.43  POINT (-76.6183 2.4332)
# 3                28                         0.32  POINT (-76.6183 2.4332)
# 4                28                         0.32  POINT (-76.6183 2.4332)

# %%
df['ciudad'].value_counts().head(20)
# Out:
# ciudad
# Bogota_BOGOTA                5368006
# Cali_VALLE_DEL_CAUCA         1891898
# Chia_CUNDINAMARCA            1700339
# Villavicencio_META           1438202
# Cucuta_NORTE_DE_SANTANDER    1144697
# Barranquilla_ATLANTICO       1010506
# Ibague_TOLIMA                 994802
# Valledupar_CESAR              983952
# Pereira_RISARALDA             854576
# Medellin_ANTIOQUIA            769710
# Santa_Marta_MAGDALENA         766443
# Zipaquira_CUNDINAMARCA        738160
# Armenia_QUINDIO               699331
# Cajica_CUNDINAMARCA           686921
# Neiva_HUILA                   666230
# Manizales_CALDAS              558574
# Dosquebradas_RISARALDA        525915
# Pasto_NARIÑO                  514051
# Bucaramanga_SANTANDER         496163
# Cartagena_BOLIVAR             493680
# Name: count, dtype: int64

# %%
bogota = df[df['ciudad'].str.contains('Bogot', case=False, na=False)]

print(bogota.shape)
bogota.sample(10)
# Out:
# (5368006, 7)
#                       ubicacion_sonda         ciudad          fecha_medicion  \
# 8767847                 Bogota_BOSA_2  Bogota_BOGOTA  2016/12/21 09:30:00 AM
# 8278015                 Bogota_MINTIC  Bogota_BOGOTA  2023/08/17 12:30:00 AM
# 12344751        Bogota_SUBA_TIBABUYES  Bogota_BOGOTA  2017/03/08 10:18:00 AM
# 8703483              Bogota_CARABELAS  Bogota_BOGOTA  2023/04/14 03:12:00 PM
# 8879208                 Bogota_BOSA_2  Bogota_BOGOTA  2019/04/05 06:30:00 AM
# 10438223                   Bogota_ANE  Bogota_BOGOTA  2022/05/05 01:06:00 AM
# 14194488  Bogota_AEROPUERTO_GUAYMARAL  Bogota_BOGOTA  2021/12/08 09:54:00 AM
# 8454159              Bogota_CARABELAS  Bogota_BOGOTA  2019/11/19 08:12:00 AM
# 10763733             Bogota_AEROCIVIL  Bogota_BOGOTA  2023/05/20 03:24:00 AM
# 8370297              Bogota_CARABELAS  Bogota_BOGOTA  2018/12/04 05:42:00 PM
#
#           intensidad_campo  máximo_permitido  porcentaje_intensidad_campo  \
# 8767847               1.98                28                         7.07
# 8278015               1.34                28                         4.79
# 12344751              0.04                28                         0.14
# 8703483               2.09                28                         7.46
# 8879208               1.74                28                         6.21
# 10438223              0.52                28                         1.86
# 14194488              1.91                28                         6.82
# 8454159               0.75                28                         2.68
# 10763733              6.06                28                        21.64
# 8370297               0.72                28                         2.57
#
#                                     georreferencia
# 8767847              POINT (-74.1688982 4.6257219)
# 8278015                  POINT (-74.074698 4.5999)
# 12344751             POINT (-74.1098888 4.7441229)
# 8703483                    POINT (-74.1182 4.6064)
# 8879208              POINT (-74.1688982 4.6257219)
# 10438223  POINT (-74.053997817986 4.6776376127524)
# 14194488  POINT (-74.069666666666 4.8166388888889)
# 8454159                    POINT (-74.1182 4.6064)
# 10763733                POINT (-74.139405 4.69578)
# 8370297                    POINT (-74.1182 4.6064)

# %%
bogota['ciudad'].value_counts()
# Out:
# ciudad
# Bogota_BOGOTA    5368006
# Name: count, dtype: int64

# %%
bogota = bogota.copy()

# tipos de datos correctos
bogota['fecha_medicion'] = pd.to_datetime(bogota['fecha_medicion'], errors='coerce')
bogota['intensidad_campo'] = pd.to_numeric(bogota['intensidad_campo'], errors='coerce')
bogota['máximo_permitido'] = pd.to_numeric(bogota['máximo_permitido'], errors='coerce')
bogota['porcentaje_intensidad_campo'] = pd.to_numeric(bogota['porcentaje_intensidad_campo'], errors='coerce')

# eliminamos nulos
bogota = bogota.dropna()

# eliminamos duplicados
bogota = bogota.drop_duplicates()

# reseteamos el índice
bogota = bogota.reset_index(drop=True)

print(f"Filas después de limpiar: {bogota.shape[0]:,}")
print(f"\nTipos de datos:\n{bogota.dtypes}")
print(f"\nNulos restantes:\n{bogota.isnull().sum()}")
# Out:
# /tmp/ipykernel_4815/3531296307.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bogota['fecha_medicion'] = pd.to_datetime(bogota['fecha_medicion'], errors='coerce')

# %%
bogota['georreferencia'].head(10)

# %%
bogota.to_csv('bogota_rni_limpio.csv', index=False)
print("Archivo guardado!")

# %%
bogota[['longitud', 'latitud']] = bogota['georreferencia'].str.extract(r'POINT \(([^ ]+) ([^ ]+)\)').astype(float)

print(bogota[['georreferencia', 'longitud', 'latitud']].head())

# %%
bogota.to_csv('bogota_rni_limpio.csv', index=False)
print("Archivo actualizado con coordenadas!")
print(bogota.columns.tolist())

# %%
resumen = bogota.groupby('ubicacion_sonda')['intensidad_campo'].agg(['mean', 'median', 'max', 'min']).reset_index()
resumen = resumen.sort_values('mean', ascending=False)
print(f"Total ubicaciones únicas: {resumen.shape[0]}")
resumen.head(20)

# %%
ubicaciones_top10 = [
    'Bogota_BATAN',
    'Bogota_CENTRO_COMERCIAL_GRAN_ESTACION',
    'Bogota_AEROCIVIL',
    'Bogota_HOSPITAL_DE_LA_POLICIA',
    'Bogota_EDIFICIO_CLARO',
    'Bogota_DIPOL_(DIRECCION_DE_INTELIGENCIA_POLICIAL)',
    'Bogota_QUIRIGUA',
    'Bogota_LA_ESTRADA',
    'Bogota_SUBA_TIBABUYES',
    'Bogota_CEDRITOS'
]

bogota_top10 = bogota[bogota['ubicacion_sonda'].isin(ubicaciones_top10)]
print(bogota_top10.shape)
bogota_top10['ubicacion_sonda'].value_counts()

# %%
bogota_top10.to_csv('bogota_top10.csv', index=False)
print("Archivo bogota_top10.csv guardado!")
print(f"Total filas: {bogota_top10.shape[0]:,}")

# %%
bogota_app = bogota_top10.groupby(
    ['ubicacion_sonda', pd.Grouper(key='fecha_medicion', freq='D')]
).agg(
    intensidad_promedio=('intensidad_campo', 'mean'),
    maximo_permitido=('máximo_permitido', 'first'),
    porcentaje_promedio=('porcentaje_intensidad_campo', 'mean'),
    latitud=('latitud', 'first'),
    longitud=('longitud', 'first')
).reset_index()

bogota_app.to_csv('bogota_app.csv', index=False)
print(f"Filas: {bogota_app.shape[0]:,}")
print(bogota_app.head())

# %%
mapa_check = df[['ubicacion_sonda', 'latitud', 'longitud']].drop_duplicates()
print(mapa_check)
